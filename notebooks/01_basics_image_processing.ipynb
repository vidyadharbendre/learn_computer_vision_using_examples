# %%
# 01_basic_image_processing.ipynb

# Basic Image Processing without Functions

# Import necessary libraries
import cv2
import matplotlib.pyplot as plt

# %%
import cv2
import os

# Path to the image
image_path = os.path.join(os.getcwd(), 'data', 'images', 'roses.jpg')
# Load the image
image = cv2.imread(image_path)

# Check if the image was loaded properly
if image is None:
    print("Error: Image could not be loaded.")
else:
    # Coordinates for the pixel
    x = 100  # X-coordinate
    y = 50   # Y-coordinate

    # Get the pixel value at (x, y)
    pixel_value = image[y, x]  # Note: in OpenCV, it's (y, x) not (x, y)

    # The pixel value will be in BGR format
    blue, green, red = pixel_value

    # Print the pixel values
    print(f"Pixel value at ({x}, {y}) - BGR: {pixel_value}")
    print(f"Blue: {blue}, Green: {green}, Red: {red}")
# Out:
# Pixel value at (100, 50) - BGR: [ 0 37 21]
# Blue: 0, Green: 37, Red: 21

# %%
# Using an absolute path is more reliable
image_path = os.path.join(os.getcwd(), 'data', 'images', 'roses.jpg')

image = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
import cv2
import os

# Construct the image path dynamically from the current working directory
image_path = os.path.join(os.getcwd(), 'data', 'images', 'roses.jpg')

# Load the image
image = cv2.imread(image_path)

# Check if the image was loaded properly
if image is None:
    print(f"Error: Image could not be loaded. Please check the file path: {image_path}")
else:
    print(f"Image loaded successfully from: {image_path}")
    
    # Access pixel values at (x, y)
    x, y = 100, 50  # Example coordinates
    pixel_values = image[y, x]  # OpenCV uses (y, x) format
    
    # Print BGR pixel values
    print(f"BGR values at pixel ({x}, {y}): {pixel_values}")

    # Convert BGR to RGB
    rgb_values = (pixel_values[2], pixel_values[1], pixel_values[0])  # Convert to RGB
    print(f"RGB values at pixel ({x}, {y}): {rgb_values}")
# Out:
# Image loaded successfully from: /Users/vidyadharbendre/workspace/learn_computer_vision_using_examples/notebooks/data/images/roses.jpg
# BGR values at pixel (100, 50): [ 0 37 21]
# RGB values at pixel (100, 50): (21, 37, 0)

# %%
import cv2
import os

# Construct the image path dynamically from the current working directory
image_path = os.path.join(os.getcwd(), 'data', 'images', 'roses.jpg')

# Load the image
image = cv2.imread(image_path)

# Check if the image was loaded properly
if image is None:
    print(f"Error: Image could not be loaded. Please check the file path: {image_path}")
else:
    print(f"Image loaded successfully from: {image_path}")
    
    # Access pixel values at (x, y)
    x, y = 100, 50  # Example coordinates
    pixel_values = image[y, x]  # OpenCV uses (y, x) format
    
    # Print BGR pixel values
    print(f"BGR values at pixel ({x}, {y}): {pixel_values}")

    # Convert BGR to RGB
    rgb_values = (pixel_values[2], pixel_values[1], pixel_values[0])  # Convert to RGB
    print(f"RGB values at pixel ({x}, {y}): {rgb_values}")
    
    # Convert RGB to hex (6-digit)
    hex_value = '#{:02x}{:02x}{:02x}'.format(rgb_values[0], rgb_values[1], rgb_values[2]).upper()
    print(f"Hex code at pixel ({x}, {y}): {hex_value}")
# Out:
# Image loaded successfully from: /Users/vidyadharbendre/workspace/learn_computer_vision_using_examples/notebooks/data/images/roses.jpg
# BGR values at pixel (100, 50): [ 0 37 21]
# RGB values at pixel (100, 50): (21, 37, 0)
# Hex code at pixel (100, 50): #152500

# %%
hex_value = '#{:02x}{:02x}{:02x}'.format(rgb_values[0], rgb_values[1], rgb_values[2]).upper()
hex_value
# Out:
# '#152500'

# %%
pixel_values
# Out:
# array([ 0, 37, 21], dtype=uint8)

# %%
import cv2
import os
import matplotlib.pyplot as plt

# Absolute path to the image
image_path = '/Users/your_username/path_to_directory/roses.jpg'

# Check if file exists
if not os.path.exists(image_path):
    print(f"Error: The file {image_path} does not exist.")
else:
    # Load the image
    image = cv2.imread(image_path)
    
    # Check if the image is successfully loaded
    if image is None:
        print("Error: Image could not be loaded. Check the file format and path.")
    else:
        # Convert to RGB for matplotlib
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # Display the image
        plt.imshow(image_rgb)
        plt.axis('off')  # Hide the axes
        plt.show()
# Out:
# Error: The file /Users/your_username/path_to_directory/roses.jpg does not exist.

# %%
image_path
# Out:
# 'roses.jpg'

# %%
os.getcwd()
# Out:
# '/Users/vidyadharbendre/workspace/learn_computer_vision_using_examples/notebooks'

# %%
if os.path.exists('/Users/vidyadharbendre/workspace/learn_computer_vision_using_examples/notebooks/data/images/roses.jpg'):
                  print('Image found')
# Out:
# Image found

# %%
import cv2
import os

# Step 1: Load the image
image_path = os.path.join(os.getcwd(), 'data', 'images', 'roses.jpg')
image = cv2.imread(image_path)

# Check if the image was loaded properly
if image is None:
    print(f"Error: Image could not be loaded. Please check the file path: {image_path}")
else:
    print(f"Image loaded successfully from: {image_path}")
    
    # Step 2: Access pixel values at (x, y)
    x, y = 100, 50  # Example coordinates
    pixel_values = image[y, x]  # OpenCV uses (y, x) format
    
    # Print BGR pixel values
    print(f"BGR values at pixel ({x}, {y}): {pixel_values}")

    # Step 3: Convert BGR to RGB
    rgb_values = (pixel_values[2], pixel_values[1], pixel_values[0])  # Convert BGR to RGB
    print(f"RGB values at pixel ({x}, {y}): {rgb_values}")
    
    # Step 4: Convert RGB to Hex (6-digit code)
    hex_value = '#{:02x}{:02x}{:02x}'.format(rgb_values[0], rgb_values[1], rgb_values[2]).upper()
    print(f"Hex code at pixel ({x}, {y}): {hex_value}")

    # Step 5: Convert Hex back to RGB
    def hex_to_rgb(hex_val):
        hex_val = hex_val.lstrip('#')  # Remove the hash (#) from the beginning
        return tuple(int(hex_val[i:i+2], 16) for i in (0, 2, 4))  # Convert back to RGB

    rgb_from_hex = hex_to_rgb(hex_value)
    print(f"RGB values from Hex {hex_value}: {rgb_from_hex}")

    # Final output: display the original RGB and RGB from Hex to verify correctness
    print(f"Original RGB values: {rgb_values}")
    print(f"RGB from Hex: {rgb_from_hex}")
# Out:
# Image loaded successfully from: /Users/vidyadharbendre/workspace/learn_computer_vision_using_examples/notebooks/data/images/roses.jpg
# BGR values at pixel (100, 50): [ 0 37 21]
# RGB values at pixel (100, 50): (21, 37, 0)
# Hex code at pixel (100, 50): #152500
# RGB values from Hex #152500: (21, 37, 0)
# Original RGB values: (21, 37, 0)
# RGB from Hex: (21, 37, 0)

# %%
import cv2
import os

# Construct the image path dynamically from the current working directory
image_path = os.path.join(os.getcwd(), 'data', 'images', 'roses.jpg')

# Load the image
image = cv2.imread(image_path)

# Check if the image was loaded properly
if image is None:
    print(f"Error: Image could not be loaded. Please check the file path: {image_path}")
else:
    print(f"Image loaded successfully from: {image_path}")
    
    # Access pixel values at (x, y)
    x, y = 100, 50  # Example coordinates
    pixel_values = image[y, x]  # OpenCV uses (y, x) format
    
    # Print BGR pixel values
    print(f"BGR values at pixel ({x}, {y}): {pixel_values}")

    # Convert BGR to RGB
    rgb_values = (pixel_values[2], pixel_values[1], pixel_values[0])  # Convert to RGB
    print(f"RGB values at pixel ({x}, {y}): {rgb_values}")
    
    # Convert RGB to hex (6-digit)
    hex_value = '#{:02x}{:02x}{:02x}'.format(rgb_values[0], rgb_values[1], rgb_values[2]).upper()
    print(f"Hex code at pixel ({x}, {y}): {hex_value}")
# Out:
# Image loaded successfully from: /Users/vidyadharbendre/workspace/learn_computer_vision_using_examples/notebooks/data/images/roses.jpg
# BGR values at pixel (100, 50): [ 0 37 21]
# RGB values at pixel (100, 50): (21, 37, 0)
# Hex code at pixel (100, 50): #152500
